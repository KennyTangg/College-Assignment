# %% [markdown]
# ---
# title: "My Report"
# format: html
# jupyter: python3
# ---
#
# ### Setup and Data Loading

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# Display settings
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)

# Load datasets
df = pd.read_csv("data/steam.csv")
df2 = pd.read_csv("data/steam_support_info.csv")

# %% [markdown]
# ### Inspect Data
# checking the structure, missing values and information for both datasets
#
# #### First Dataset

# %%
df.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
df.tail()
# Out:
#          appid                        name release_date  english  \
# 27070  1065230             Room of Pandora   2019-04-24        1
# 27071  1065570                   Cyber Gun   2019-04-23        1
# 27072  1065650            Super Star Blast   2019-04-24        1
# 27073  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 27074  1069460                   Rune Lord   2019-04-24        1
#
#                 developer             publisher    platforms  required_age  \
# 27070         SHEN JIAWEI           SHEN JIAWEI      windows             0
# 27071      Semyon Maximov      BekkerDev Studio      windows             0
# 27072         EntwicklerX           EntwicklerX      windows             0
# 27073  Yustas Game Studio  Alawar Entertainment  windows;mac             0
# 27074    Adept Studios GD  Alawar Entertainment  windows;mac             0
#
#                                               categories  \
# 27070                   Single-player;Steam Achievements
# 27071                                      Single-player
# 27072  Single-player;Multi-player;Co-op;Shared/Split ...
# 27073                          Single-player;Steam Cloud
# 27074                          Single-player;Steam Cloud
#
#                        genres           steamspy_tags  achievements  \
# 27070  Adventure;Casual;Indie  Adventure;Indie;Casual             7
# 27071  Action;Adventure;Indie  Action;Indie;Adventure             0
# 27072     Action;Casual;Indie     Action;Indie;Casual            24
# 27073  Adventure;Casual;Indie  Indie;Casual;Adventure             0
# 27074  Adventure;Casual;Indie  Indie;Casual;Adventure             0
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 27070                 3                 0                 0                0
# 27071                 8                 1                 0                0
# 27072                 0                 1                 0                0
# 27073                 2                 0                 0                0
# 27074                 4                 0                 0                0
#
#         owners  price
# 27070  0-20000   2.09
# 27071  0-20000   1.69
# 27072  0-20000   3.99
# 27073  0-20000   5.19
# 27074  0-20000   5.19

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27075 entries, 0 to 27074
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   appid             27075 non-null  int64
#  1   name              27075 non-null  object
#  2   release_date      27075 non-null  object
#  3   english           27075 non-null  int64
#  4   developer         27074 non-null  object
#  5   publisher         27061 non-null  object
#  6   platforms         27075 non-null  object
#  7   required_age      27075 non-null  int64
#  8   categories        27075 non-null  object
#  9   genres            27075 non-null  object
#  10  steamspy_tags     27075 non-null  object
#  11  achievements      27075 non-null  int64
#  12  positive_ratings  27075 non-null  int64
#  13  negative_ratings  27075 non-null  int64
#  14  average_playtime  27075 non-null  int64
#  15  median_playtime   27075 non-null  int64
#  16  owners            27075 non-null  object
#  17  price             27075 non-null  float64
# dtypes: float64(1), int64(8), object(9)
# memory usage: 3.7+ MB
#               appid       english  required_age  achievements  \
# count  2.707500e+04  27075.000000  27075.000000  27075.000000
# mean   5.962035e+05      0.981127      0.354903     45.248864
# std    2.508942e+05      0.136081      2.406044    352.670281
# min    1.000000e+01      0.000000      0.000000      0.000000
# 25%    4.012300e+05      1.000000      0.000000      0.000000
# 50%    5.990700e+05      1.000000      0.000000      7.000000
# 75%    7.987600e+05      1.000000      0.000000     23.000000
# max    1.069460e+06      1.000000     18.000000   9821.000000
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# count      2.707500e+04      27075.000000      27075.000000      27075.00000
# mean       1.000559e+03        211.027147        149.804949        146.05603
# std        1.898872e+04       4284.938531       1827.038141       2353.88008
# min        0.000000e+00          0.000000          0.000000          0.00000
# 25%        6.000000e+00          2.000000          0.000000          0.00000
# 50%        2.400000e+01          9.000000          0.000000          0.00000
# 75%        1.260000e+02         42.000000          0.000000          0.00000
# max        2.644404e+06     487076.000000     190625.000000     190625.00000
#
#               price
# count  27075.000000
# mean       6.078193
# std        7.874922
# min        0.000000
# 25%        1.690000
# 50%        3.990000
# 75%        7.190000
# max      421.990000

# %% [markdown]
# #### Second Dataset

# %%
df2.head()
# Out:
#    steam_appid                      website                       support_url  \
# 0           10                          NaN  http://steamcommunity.com/app/10
# 1           30  http://www.dayofdefeat.com/                               NaN
# 2           50                          NaN     https://help.steampowered.com
# 3           70    http://www.half-life.com/  http://steamcommunity.com/app/70
# 4           80                          NaN  http://steamcommunity.com/app/80
#
#   support_email
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df2.info()
# won't work
df2.describe()
df2.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27136 entries, 0 to 27135
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   steam_appid    27136 non-null  int64
#  1   website        18015 non-null  object
#  2   support_url    16479 non-null  object
#  3   support_email  23500 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 848.1+ KB
# steam_appid          0
# website           9121
# support_url      10657
# support_email     3636
# dtype: int64

# %% [markdown]
# ### Handling Missing Values
# impute missing values in `df` and `df2`

# %%
df["developer"] = df["developer"].fillna("Unknown")
df["publisher"] = df["publisher"].fillna("Unknown")

# Can be Alternative either drop the NaN or just fill it with "Missing"
# df2 = df2.dropna()
df2 = df2.fillna("Missing")

# %% [markdown]
# ### Modify Index and Column Names
# modify index and rename columns (for merge)

# %%
# set PK as index
df = df.set_index("appid")

# rename index
df.index.name = "appid_index"

# reset back to column
df = df.reset_index()

# change index value to start from 1 
df.index = range(1, 1 + len(df))

# change back the name (for easier merging)
if "appid_index" in df.columns:
    df = df.rename(columns = {"appid_index": "appid"})

df2 = df2.rename(columns={"steam_appid": "appid"})
df.head()
# Out:
#    appid                       name release_date  english         developer  \
# 1     10             Counter-Strike   2000-11-01        1             Valve
# 2     20      Team Fortress Classic   1999-04-01        1             Valve
# 3     30              Day of Defeat   2003-05-01        1             Valve
# 4     40         Deathmatch Classic   2001-06-01        1             Valve
# 5     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
# 5     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 3              Multi-player;Valve Anti-Cheat enabled  Action
# 4  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 5  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 1        Action;FPS;Multiplayer             0            124534
# 2        Action;FPS;Multiplayer             0              3318
# 3  FPS;World War II;Multiplayer             0              3416
# 4        Action;FPS;Multiplayer             0              1273
# 5             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 1              3339             17612              317  10000000-20000000
# 2               633               277               62   5000000-10000000
# 3               398               187               34   5000000-10000000
# 4               267               258              184   5000000-10000000
# 5               288               624              415   5000000-10000000
#
#    price
# 1   7.19
# 2   3.99
# 3   3.99
# 4   3.99
# 5   3.99

# %% [markdown]
# ### Reshape Dataframes
# reshape using `melt` and `pivot`

# %%
df_melted = df.melt(
    id_vars=["appid", "name"],
    value_vars=["average_playtime", "median_playtime"],
    var_name="playtime_type",
    value_name="minutes"
)

df_melted.head()
# Out:
#    appid                       name     playtime_type  minutes
# 0     10             Counter-Strike  average_playtime    17612
# 1     20      Team Fortress Classic  average_playtime      277
# 2     30              Day of Defeat  average_playtime      187
# 3     40         Deathmatch Classic  average_playtime      258
# 4     50  Half-Life: Opposing Force  average_playtime      624

# %%
df_pivoted = df_melted.pivot(
    index=["appid", "name"],
    columns="playtime_type",
    values="minutes"
).reset_index()

df_pivoted.columns.name = None
df_pivoted.head()
# Out:
#    appid                       name  average_playtime  median_playtime
# 0     10             Counter-Strike             17612              317
# 1     20      Team Fortress Classic               277               62
# 2     30              Day of Defeat               187               34
# 3     40         Deathmatch Classic               258              184
# 4     50  Half-Life: Opposing Force               624              415

# %% [markdown]
# ### Merge 2 Dataset
# combine and concatenate both dataframes

# %%
df_merge = df.merge(df2, on="appid")
df_merge.head()
# Out:
#    appid                            name release_date  english  \
# 0     10                  Counter-Strike   2000-11-01        1
# 1     30                   Day of Defeat   2003-05-01        1
# 2     50       Half-Life: Opposing Force   1999-11-01        1
# 3     70                       Half-Life   1998-11-08        1
# 4     80  Counter-Strike: Condition Zero   2004-03-01        1
#
#           developer publisher          platforms  required_age  \
# 0             Valve     Valve  windows;mac;linux             0
# 1             Valve     Valve  windows;mac;linux             0
# 2  Gearbox Software     Valve  windows;mac;linux             0
# 3             Valve     Valve  windows;mac;linux             0
# 4             Valve     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1              Multi-player;Valve Anti-Cheat enabled  Action
# 2  Single-player;Multi-player;Valve Anti-Cheat en...  Action
# 3  Single-player;Multi-player;Online Multi-Player...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1  FPS;World War II;Multiplayer             0              3416
# 2             FPS;Action;Sci-fi             0              5250
# 3            FPS;Classic;Action             0             27755
# 4        Action;FPS;Multiplayer             0             12120
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               398               187               34   5000000-10000000
# 2               288               624              415   5000000-10000000
# 3              1100              1300               83   5000000-10000000
# 4              1439               427               43  10000000-20000000
#
#    price                      website                       support_url  \
# 0   7.19                      Missing  http://steamcommunity.com/app/10
# 1   3.99  http://www.dayofdefeat.com/                           Missing
# 2   3.99                      Missing     https://help.steampowered.com
# 3   7.19    http://www.half-life.com/  http://steamcommunity.com/app/70
# 4   7.19                      Missing  http://steamcommunity.com/app/80
#
#   support_email
# 0       Missing
# 1       Missing
# 2       Missing
# 3       Missing
# 4       Missing

# %%
# concat horizontally (column)
df_concat = pd.concat([df, df2], axis=1)
df_concat.head()
# Out:
#    appid                       name release_date  english         developer  \
# 1   10.0             Counter-Strike   2000-11-01      1.0             Valve
# 2   20.0      Team Fortress Classic   1999-04-01      1.0             Valve
# 3   30.0              Day of Defeat   2003-05-01      1.0             Valve
# 4   40.0         Deathmatch Classic   2001-06-01      1.0             Valve
# 5   50.0  Half-Life: Opposing Force   1999-11-01      1.0  Gearbox Software
#
#   publisher          platforms  required_age  \
# 1     Valve  windows;mac;linux           0.0
# 2     Valve  windows;mac;linux           0.0
# 3     Valve  windows;mac;linux           0.0
# 4     Valve  windows;mac;linux           0.0
# 5     Valve  windows;mac;linux           0.0
#
#                                           categories  genres  \
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 3              Multi-player;Valve Anti-Cheat enabled  Action
# 4  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 5  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 1        Action;FPS;Multiplayer           0.0          124534.0
# 2        Action;FPS;Multiplayer           0.0            3318.0
# 3  FPS;World War II;Multiplayer           0.0            3416.0
# 4        Action;FPS;Multiplayer           0.0            1273.0
# 5             FPS;Action;Sci-fi           0.0            5250.0
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 1            3339.0           17612.0            317.0  10000000-20000000
# 2             633.0             277.0             62.0   5000000-10000000
# 3             398.0             187.0             34.0   5000000-10000000
# 4             267.0             258.0            184.0   5000000-10000000
# 5             288.0             624.0            415.0   5000000-10000000
#
#    price  appid                      website  \
# 1   7.19     30  http://www.dayofdefeat.com/
# 2   3.99     50                      Missing
# 3   3.99     70    http://www.half-life.com/
# 4   3.99     80                      Missing
# 5   3.99    130                      Missing
#
#                         support_url support_email
# 1                           Missing       Missing
# 2     https://help.steampowered.com       Missing
# 3  http://steamcommunity.com/app/70       Missing
# 4  http://steamcommunity.com/app/80       Missing
# 5     https://help.steampowered.com       Missing

# %% [markdown]
# ### Apply Function
# using `apply` and `applymap`

# %%
def pos_neg_ratio(row):
    return row["positive_ratings"] / (row["negative_ratings"] + 1)

df_merge["pos_neg_ratio"] = df_merge.apply(pos_neg_ratio, axis=1)
df_merge.head()
# Out:
#    appid                            name release_date  english  \
# 0     10                  Counter-Strike   2000-11-01        1
# 1     30                   Day of Defeat   2003-05-01        1
# 2     50       Half-Life: Opposing Force   1999-11-01        1
# 3     70                       Half-Life   1998-11-08        1
# 4     80  Counter-Strike: Condition Zero   2004-03-01        1
#
#           developer publisher          platforms  required_age  \
# 0             Valve     Valve  windows;mac;linux             0
# 1             Valve     Valve  windows;mac;linux             0
# 2  Gearbox Software     Valve  windows;mac;linux             0
# 3             Valve     Valve  windows;mac;linux             0
# 4             Valve     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1              Multi-player;Valve Anti-Cheat enabled  Action
# 2  Single-player;Multi-player;Valve Anti-Cheat en...  Action
# 3  Single-player;Multi-player;Online Multi-Player...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1  FPS;World War II;Multiplayer             0              3416
# 2             FPS;Action;Sci-fi             0              5250
# 3            FPS;Classic;Action             0             27755
# 4        Action;FPS;Multiplayer             0             12120
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               398               187               34   5000000-10000000
# 2               288               624              415   5000000-10000000
# 3              1100              1300               83   5000000-10000000
# 4              1439               427               43  10000000-20000000
#
#    price                      website                       support_url  \
# 0   7.19                      Missing  http://steamcommunity.com/app/10
# 1   3.99  http://www.dayofdefeat.com/                           Missing
# 2   3.99                      Missing     https://help.steampowered.com
# 3   7.19    http://www.half-life.com/  http://steamcommunity.com/app/70
# 4   7.19                      Missing  http://steamcommunity.com/app/80
#
#   support_email  pos_neg_ratio
# 0       Missing      37.285629
# 1       Missing       8.561404
# 2       Missing      18.166090
# 3       Missing      25.208901
# 4       Missing       8.416667

# %%
def to_lower(value):
    if isinstance(value, str):
        return value.lower()
    return value

df2_lower = df2.applymap(to_lower)
df2_lower.head()
# Out:
# /tmp/ipykernel_145302/1569788566.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2_lower = df2.applymap(to_lower)
#    appid                      website                       support_url  \
# 0     10                      missing  http://steamcommunity.com/app/10
# 1     30  http://www.dayofdefeat.com/                           missing
# 2     50                      missing     https://help.steampowered.com
# 3     70    http://www.half-life.com/  http://steamcommunity.com/app/70
# 4     80                      missing  http://steamcommunity.com/app/80
#
#   support_email
# 0       missing
# 1       missing
# 2       missing
# 3       missing
# 4       missing

# %% [markdown]
# ### Query Data
# filter data using `query`

# %%
# filter just free games
df_free_games = df_merge.query("price == 0")
df_free_games.head()
# Out:
#     appid                              name release_date  english  \
# 9     340           Half-Life 2: Lost Coast   2005-10-27        1
# 13    440                   Team Fortress 2   2007-10-10        1
# 16    570                            Dota 2   2013-07-09        1
# 18    630                       Alien Swarm   2010-07-19        1
# 19    730  Counter-Strike: Global Offensive   2012-08-21        1
#
#                           developer publisher          platforms  \
# 9                             Valve     Valve  windows;mac;linux
# 13                            Valve     Valve  windows;mac;linux
# 16                            Valve     Valve  windows;mac;linux
# 18                            Valve     Valve            windows
# 19  Valve;Hidden Path Entertainment     Valve  windows;mac;linux
#
#     required_age                                         categories  \
# 9              0                 Single-player;Commentary available
# 13             0  Multi-player;Cross-Platform Multiplayer;Steam ...
# 16             0  Multi-player;Co-op;Steam Trading Cards;Steam W...
# 18             0  Single-player;Multi-player;Co-op;Steam Achieve...
# 19             0  Multi-player;Steam Achievements;Full controlle...
#
#                           genres                 steamspy_tags  achievements  \
# 9                         Action       FPS;Action;Singleplayer             0
# 13           Action;Free to Play  Free to Play;Multiplayer;FPS           520
# 16  Action;Free to Play;Strategy    Free to Play;MOBA;Strategy             0
# 18                        Action     Free to Play;Co-op;Action            66
# 19           Action;Free to Play       FPS;Multiplayer;Shooter           167
#
#     positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 9               5783              1020                46               29
# 13            515879             34036              8495              623
# 16            863507            142079             23944              801
# 18             17435               941               371               83
# 19           2644404            402313             22494             6502
#
#                  owners  price                          website  \
# 9     10000000-20000000    0.0        http://www.half-life2.com
# 13    20000000-50000000    0.0     http://www.teamfortress.com/
# 16  100000000-200000000    0.0            http://www.dota2.com/
# 18      2000000-5000000    0.0        http://www.alienswarm.com
# 19   50000000-100000000    0.0  http://blog.counter-strike.net/
#
#                           support_url support_email  pos_neg_ratio
# 9                             Missing       Missing       5.664055
# 13  http://steamcommunity.com/app/440       Missing      15.156418
# 16              http://dev.dota2.com/       Missing       6.077611
# 18                            Missing       Missing      18.508493
# 19                            Missing       Missing       6.572985

# %%
df_good_games = df_merge.query("pos_neg_ratio > 10")
df_good_games.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 2     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
# 3     70                  Half-Life   1998-11-08        1             Valve
# 6    220                Half-Life 2   2004-11-16        1             Valve
# 7    240     Counter-Strike: Source   2004-11-01        1             Valve
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 6     Valve  windows;mac;linux             0
# 7     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2  Single-player;Multi-player;Valve Anti-Cheat en...  Action
# 3  Single-player;Multi-player;Online Multi-Player...  Action
# 6  Single-player;Steam Achievements;Steam Trading...  Action
# 7  Multi-player;Cross-Platform Multiplayer;Steam ...  Action
#
#             steamspy_tags  achievements  positive_ratings  negative_ratings  \
# 0  Action;FPS;Multiplayer             0            124534              3339
# 2       FPS;Action;Sci-fi             0              5250               288
# 3      FPS;Classic;Action             0             27755              1100
# 6       FPS;Action;Sci-fi            33             67902              2419
# 7  Action;FPS;Multiplayer           147             76640              3497
#
#    average_playtime  median_playtime             owners  price  \
# 0             17612              317  10000000-20000000   7.19
# 2               624              415   5000000-10000000   3.99
# 3              1300               83   5000000-10000000   7.19
# 6               691              402  10000000-20000000   7.19
# 7              6842              400  10000000-20000000   7.19
#
#                      website                        support_url support_email  \
# 0                    Missing   http://steamcommunity.com/app/10       Missing
# 2                    Missing      https://help.steampowered.com       Missing
# 3  http://www.half-life.com/   http://steamcommunity.com/app/70       Missing
# 6  http://www.half-life2.com  http://steamcommunity.com/app/220       Missing
# 7                    Missing  http://steamcommunity.com/app/240       Missing
#
#    pos_neg_ratio
# 0      37.285629
# 2      18.166090
# 3      25.208901
# 6      28.058678
# 7      21.909663

# %% [markdown]
# ### Grouping and Aggregating
# Aggregating data

# %%
english_stats = df_merge.groupby("english", as_index=False).agg({
    "positive_ratings": "sum",
    "negative_ratings": "sum",
    "price": "mean"
})

english_stats
# Out:
#    english  positive_ratings  negative_ratings     price
# 0        0             91420             17762  5.651157
# 1        1          26899609           5679020  6.096295

# %%
overall_stats = df_merge.agg({
    "positive_ratings": ["min", "max", "sum", "mean"],
    "negative_ratings": ["min", "max", "sum", "mean"],
    "price": ["min", "max", "sum","mean"]
})
overall_stats
# Out:
#       positive_ratings  negative_ratings          price
# min       0.000000e+00      0.000000e+00       0.000000
# max       2.644404e+06      4.870760e+05     421.990000
# sum       2.699103e+07      5.696782e+06  163647.480000
# mean      1.004093e+03      2.119260e+02       6.087849

# %% [markdown]
# ### Missing Value Imputation with scikit-learn
# create missing value and use scikit learn `SimpleImputer`

# %%
np.random.seed(50)

col_name = ['price']
mask = np.random.choice([True, False], size=df_merge[col_name].shape)

# Ensure not all are False (force at least some NaNs)
if not mask.any():
    mask[np.random.randint(0, len(df_merge))] = True

df_merge[col_name] = df_merge[col_name].mask(mask)
df_merge[col_name].isna().sum()

imputer = SimpleImputer(strategy="mean")

# fit and transform
df_merge["price"] = imputer.fit_transform(df_merge[["price"]])
df_merge["price"]
# Out:
# 0        6.069875
# 1        6.069875
# 2        3.990000
# 3        7.190000
# 4        7.190000
#            ...
# 26876    2.090000
# 26877    1.690000
# 26878    6.069875
# 26879    6.069875
# 26880    5.190000
# Name: price, Length: 26881, dtype: float64

# %% [markdown]
# ### Extra Miles
# 1. Cleaning data using regex (data is already clean , so mostly just changing data for regex)

# %%
import re

def clean_text(text):
    if isinstance(text, str):
        text = text.lower()  # lowercase everything
        text = re.sub(r"[^a-z0-9\s]", " ", text)  # remove special chars
        text = re.sub(r";", " ", text)  # replace semicolons with spaces
        text = re.sub(r"\s+", " ", text)  # remove extra spaces
        return text.strip()
    return text

df_merge["categories_clean"] = df_merge["categories"].apply(clean_text)
df_merge["genres_clean"] = df_merge["genres"].apply(clean_text)
df_merge["steamspy_tags_clean"] = df_merge["steamspy_tags"].apply(clean_text)

df_merge[["categories", "categories_clean", "genres", "genres_clean", "steamspy_tags", "steamspy_tags_clean"]].head(10)
# Out:
#                                           categories  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...
# 1              Multi-player;Valve Anti-Cheat enabled
# 2  Single-player;Multi-player;Valve Anti-Cheat en...
# 3  Single-player;Multi-player;Online Multi-Player...
# 4  Single-player;Multi-player;Valve Anti-Cheat en...
# 5                                      Single-player
# 6  Single-player;Steam Achievements;Steam Trading...
# 7  Multi-player;Cross-Platform Multiplayer;Steam ...
# 8  Multi-player;Cross-Platform Multiplayer;Steam ...
# 9                 Single-player;Commentary available
#
#                                     categories_clean  genres genres_clean  \
# 0  multi player online multi player local multi p...  Action       action
# 1              multi player valve anti cheat enabled  Action       action
# 2  single player multi player valve anti cheat en...  Action       action
# 3  single player multi player online multi player...  Action       action
# 4  single player multi player valve anti cheat en...  Action       action
# 5                                      single player  Action       action
# 6  single player steam achievements steam trading...  Action       action
# 7  multi player cross platform multiplayer steam ...  Action       action
# 8  multi player cross platform multiplayer steam ...  Action       action
# 9                 single player commentary available  Action       action
#
#                   steamspy_tags           steamspy_tags_clean
# 0        Action;FPS;Multiplayer        action fps multiplayer
# 1  FPS;World War II;Multiplayer  fps world war ii multiplayer
# 2             FPS;Action;Sci-fi             fps action sci fi
# 3            FPS;Classic;Action            fps classic action
# 4        Action;FPS;Multiplayer        action fps multiplayer
# 5             FPS;Action;Sci-fi             fps action sci fi
# 6             FPS;Action;Sci-fi             fps action sci fi
# 7        Action;FPS;Multiplayer        action fps multiplayer
# 8  FPS;World War II;Multiplayer  fps world war ii multiplayer
# 9       FPS;Action;Singleplayer       fps action singleplayer

# %% [markdown]
# 2. Clean text and nested json in link

# %%
import ast
url = "https://raw.githubusercontent.com/nnqomariyah/Fundamentals_of_Data_Science/main/week_3/data/movies_metadata.csv"
df_movies = pd.read_csv(url)
# Out:
# /tmp/ipykernel_145302/732684341.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies = pd.read_csv(url)

# %%
def parse_and_clean_json(json_str):
    try:
        parsed = ast.literal_eval(json_str)  # safely parse
        if isinstance(parsed, list):
            names = [
                item.get("name", "")
                for item in parsed
                if isinstance(item, dict) and "name" in item
            ]
            cleaned_names = [
                re.sub(r"\s+", " ", name.strip())
                for name in names
            ]
            return ", ".join(cleaned_names)
    except Exception:
        return ""
    return ""

json_columns = ["genres", "production_companies", "production_countries", "spoken_languages"]

for col in json_columns:
    df_movies[col + "_clean"] = df_movies[col].apply(parse_and_clean_json)

df_movies["overview_clean"] = df_movies["overview"].apply(clean_text)

df_movies[[
    "title", "genres_clean", "production_companies_clean",
    "production_countries_clean", "spoken_languages_clean", "overview_clean"
]].head(5)
# Out:
#                          title                genres_clean  \
# 0                    Toy Story   Animation, Comedy, Family
# 1                      Jumanji  Adventure, Fantasy, Family
# 2             Grumpier Old Men             Romance, Comedy
# 3            Waiting to Exhale      Comedy, Drama, Romance
# 4  Father of the Bride Part II                      Comedy
#
#                           production_companies_clean  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures
#
#   production_countries_clean spoken_languages_clean  \
# 0   United States of America                English
# 1   United States of America      English, Français
# 2   United States of America                English
# 3   United States of America                English
# 4   United States of America                English
#
#                                       overview_clean
# 0  led by woody andy s toys live happily in his r...
# 1  when siblings judy and peter discover an encha...
# 2  a family wedding reignites the ancient feud be...
# 3  cheated on mistreated and stepped on the women...
# 4  just when george banks has recovered from his ...
